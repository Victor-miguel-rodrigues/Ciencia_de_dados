# %%
import numpy as np


matrix = np.random.rand(3,3) * 10
print(matrix)

matrix_round = [[round(x,2) for x in linha] for linha in matrix]
print("\n",matrix_round)
# Out:
# [[9.76612742 7.49753482 8.11856383]
#  [9.9073093  3.83764753 6.0551528 ]
#  [0.18397728 4.5135704  0.44320041]]
#
#  [[np.float64(9.77), np.float64(7.5), np.float64(8.12)], [np.float64(9.91), np.float64(3.84), np.float64(6.06)], [np.float64(0.18), np.float64(4.51), np.float64(0.44)]]
