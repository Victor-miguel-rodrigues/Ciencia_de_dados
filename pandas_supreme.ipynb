# %%
import pandas as pd
import numpy as np

try:
    archive = pd.read_csv("ecoomerce.csv")
    art = archive[archive["delivery_time_days"] < 8]
    print("\nTempo de entrega ate 7 dias")
    display(art.sort_values(by='delivery_time_days',ascending=True))
    

    tardio = archive[archive["delivery_time_days"] > 7]
    print("\ntempo de entrega maior que 7 dias")
    display(tardio.sort_values(["delivery_time_days"], ascending=False))
    
    if(archive[archive["review_score"] < 3].all):
        print("Score ruim abaixo de 3 estrelas")
        display(archive[archive["review_score"] <= 2])

except Exception as error:
    print(f"ERRor ?={error}")
# Out:
# Tempo de entrega ate 7 dias
#     order_id        date customer_id            city state product_category  \
# 3       1004  2025-01-05        C001       Sao Paulo    SP      Eletronicos
# 0       1001  2025-01-02        C001       Sao Paulo    SP      Eletronicos
# 11      1012  2025-01-13        C010        Campinas    SP      Eletronicos
# 18      1019  2025-01-20        C009         Goiania    GO      Eletronicos
# 7       1008  2025-01-09        C002  Rio de Janeiro    RJ      Eletronicos
# 15      1016  2025-01-17        C006       Fortaleza    CE      Eletronicos
# 2       1003  2025-01-04        C003  Belo Horizonte    MG             Casa
# 10      1011  2025-01-12        C009         Goiania    GO             Casa
# 5       1006  2025-01-07        C005        Salvador    BA             Moda
# 9       1010  2025-01-11        C008          Recife    PE             Moda
# 13      1014  2025-01-15        C004        Curitiba    PR             Casa
# 17      1018  2025-01-19        C008          Recife    PE             Casa
# 1       1002  2025-01-03        C002  Rio de Janeiro    RJ             Moda
# 12      1013  2025-01-14        C003  Belo Horizonte    MG             Moda
#
#     price  freight_value  delivery_time_days  review_score
# 3     800             40                   2             5
# 0    1200             50                   3             5
# 11   1500             55                   3             5
# 18   2000             60                   3             5
# 7    2200             60                   4             5
# 15    900             50                   4             5
# 2     350             25                   5             4
# 10    400             20                   5             4
# 5     300             35                   6             3
# 9     250             30                   6             3
# 13    600             35                   6             4
# 17    450             25                   6             4
# 1     200             30                   7             3
# 12    220             25                   7             3
# tempo de entrega maior que 7 dias
#     order_id        date customer_id          city state product_category  \
# 14      1015  2025-01-16        C005      Salvador    BA          Esporte
# 4       1005  2025-01-06        C004      Curitiba    PR          Esporte
# 8       1009  2025-01-10        C007  Porto Alegre    RS          Esporte
# 19      1020  2025-01-21        C010      Campinas    SP          Esporte
# 6       1007  2025-01-08        C006     Fortaleza    CE             Casa
# 16      1017  2025-01-18        C007  Porto Alegre    RS             Moda
#
#     price  freight_value  delivery_time_days  review_score
# 14    130             20                  11             2
# 4     150             20                  10             2
# 8     180             25                   9             2
# 19    160             20                   9             2
# 6     500             45                   8             4
# 16    270             30                   8             3
# Score ruim abaixo de 3 estrelas
#     order_id        date customer_id          city state product_category  \
# 4       1005  2025-01-06        C004      Curitiba    PR          Esporte
# 8       1009  2025-01-10        C007  Porto Alegre    RS          Esporte
# 14      1015  2025-01-16        C005      Salvador    BA          Esporte
# 19      1020  2025-01-21        C010      Campinas    SP          Esporte
#
#     price  freight_value  delivery_time_days  review_score
# 4     150             20                  10             2
# 8     180             25                   9             2
# 14    130             20                  11             2
# 19    160             20                   9             2
